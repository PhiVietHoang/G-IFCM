# %%
import algorithm as al
import numpy as np
import pandas as pd

# %%
# train = pd.read_excel('../archive/Raisin_Dataset.xlsx')
train = pd.read_csv('../data/iris/iris.data', header=None)
label_mapping = {'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3}
train[4] = train[4].map(label_mapping)
train
# Out:
#        0    1    2    3  4
# 0    5.1  3.5  1.4  0.2  1
# 1    4.9  3.0  1.4  0.2  1
# 2    4.7  3.2  1.3  0.2  1
# 3    4.6  3.1  1.5  0.2  1
# 4    5.0  3.6  1.4  0.2  1
# ..   ...  ...  ...  ... ..
# 145  6.7  3.0  5.2  2.3  3
# 146  6.3  2.5  5.0  1.9  3
# 147  6.5  3.0  5.2  2.0  3
# 148  6.2  3.4  5.4  2.3  3
# 149  5.9  3.0  5.1  1.8  3
#
# [150 rows x 5 columns]

# %%
train = train.to_numpy()
R_train = train[:, 0:-1]
R_train
# R_train = np.random.rand(100, 10)
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
M, N, H = al.method1(R_train, 0.45)

M = np.around(M, 3)
N = np.around(N, 3)
H = np.around(H, 3)

print ("M = ",M)
print ("\nN = ",N)
print ("\nH = ",H)
# Out:
# M =  [[0.017 0.024 0.015 0.015]
#  [0.017 0.023 0.015 0.015]
#  [0.016 0.022 0.014 0.014]
#  [0.017 0.022 0.014 0.014]
#  [0.017 0.023 0.014 0.014]
#  [0.018 0.024 0.015 0.015]
#  [0.017 0.023 0.014 0.014]
#  [0.017 0.024 0.015 0.015]
#  [0.016 0.02  0.014 0.014]
#  [0.017 0.023 0.015 0.014]
#  [0.017 0.024 0.015 0.015]
#  [0.017 0.024 0.015 0.015]
#  [0.016 0.022 0.014 0.014]
#  [0.015 0.019 0.013 0.013]
#  [0.016 0.021 0.014 0.014]
#  [0.016 0.02  0.014 0.014]
#  [0.017 0.023 0.015 0.015]
#  [0.018 0.024 0.015 0.015]
#  [0.018 0.024 0.015 0.015]
#  [0.017 0.023 0.015 0.015]
#  [0.018 0.025 0.016 0.016]
#  [0.018 0.024 0.015 0.015]
#  [0.015 0.021 0.013 0.013]
#  [0.019 0.026 0.017 0.017]
#  [0.017 0.024 0.015 0.015]
#  [0.018 0.023 0.015 0.015]
#  [0.018 0.025 0.016 0.016]
#  [0.018 0.024 0.015 0.015]
#  [0.017 0.024 0.015 0.015]
#  [0.017 0.023 0.015 0.015]
#  [0.017 0.023 0.015 0.015]
#  [0.019 0.025 0.016 0.016]
#  [0.016 0.02  0.013 0.013]
#  [0.016 0.02  0.013 0.013]
#  [0.017 0.023 0.015 0.014]
#  [0.017 0.023 0.015 0.015]
#  [0.017 0.024 0.015 0.015]
#  [0.017 0.023 0.015 0.014]
#  [0.016 0.021 0.014 0.014]
#  [0.017 0.024 0.015 0.015]
#  [0.017 0.024 0.015 0.015]
#  [0.015 0.018 0.014 0.014]
#  [0.016 0.021 0.014 0.014]
#  [0.019 0.025 0.016 0.016]
#  [0.018 0.024 0.015 0.015]
#  [0.017 0.023 0.015 0.015]
#  [0.017 0.023 0.014 0.014]
#  [0.016 0.022 0.014 0.014]
#  [0.017 0.024 0.015 0.015]
#  [0.403 0.352 0.413 0.417]
#  [0.385 0.341 0.394 0.397]
#  [0.348 0.302 0.349 0.356]
#  [0.365 0.321 0.371 0.38 ]
#  [0.4   0.345 0.411 0.419]
#  [0.401 0.353 0.413 0.42 ]
#  [0.387 0.331 0.395 0.404]
#  [0.372 0.321 0.38  0.39 ]
#  [0.377 0.325 0.384 0.394]
#  [0.388 0.341 0.4   0.408]
#  [0.372 0.32  0.379 0.389]
#  [0.361 0.315 0.366 0.376]
#  [0.381 0.327 0.39  0.4  ]
#  [0.387 0.336 0.399 0.405]
#  [0.399 0.341 0.411 0.42 ]
#  [0.371 0.327 0.377 0.387]
#  [0.397 0.35  0.409 0.417]]

# %%
# Chuẩn bị dữ liệu cho phân cụm
X = np.dstack((M, N, H))
P = X.shape[0]
true_labels = train[:, -1]

# Danh sách các hàm độ đo khoảng cách
distance_measures = {
    'distance_function': al.distance_function,
    'hamming_distance': al.hamming_distance,
    'euclidean_distance': al.euclidean_distance,
    'normalized_euclidean_distance': al.normalized_euclidean_distance,
    'hausdorff_distance': al.hausdorff_distance,
    'yang_chiclana_distance': al.yang_chiclana_distance,
    'wang_xin_distance': al.wang_xin_distance,
    'liu_jiang_distance': al.liu_jiang_distance,
    'he_distance': al.he_distance,
    'thao_distance': al.thao_distance,
    'mahanta_panda_distance': al.mahanta_panda_distance,
}

# Vòng lặp qua các độ đo
for measure_name, measure_func in distance_measures.items():
    # Phân cụm sử dụng độ đo hiện tại
    U, S = al.method3(R_train, len(np.unique(train[:, -1])), 1.7, 0.45,1, measure_name)

    # Gán nhãn dựa trên khoảng cách tới các tâm cụm
    y = np.array([np.argmin([measure_func(X[i], S[j]) for j in range(S.shape[0])]) for i in range(P)])

    # Tính toán các chỉ số đánh giá
    CA = round(al.calculate_CA(true_labels, y), 2)
    PC = round(al.calculate_PC(U), 2)
    SC = round(al.calculate_SC(X, U, S, 1.7), 2)
    XB = round(al.calculate_XB(X, U, S), 2)
    DI = round(al.calculate_DI(X, U), 2)

    # In ra các chỉ số đánh giá cho mỗi độ đo
    print(f'Measure: {measure_name}')
    print(f'  Clustering Accuracy (CA): {CA}')
    print(f'  Partition Coefficient (PC): {PC}')
    print(f'  Partition Index (SC): {SC}')
    print(f'  Xie-Beni Index (XB): {XB}')
    print(f'  Dunn Index (DI): {DI}')
    print('------------------------------------------------')
# Out:
# Measure: distance_function
#   Clustering Accuracy (CA): 0.11
#   Partition Coefficient (PC): 0.88
#   Partition Index (SC): 0.01
#   Xie-Beni Index (XB): 2.55
#   Dunn Index (DI): 0.13
# ------------------------------------------------
# Measure: hamming_distance
#   Clustering Accuracy (CA): 0.54
#   Partition Coefficient (PC): 0.73
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.31
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: euclidean_distance
#   Clustering Accuracy (CA): 0.01
#   Partition Coefficient (PC): 0.72
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.44
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: normalized_euclidean_distance
#   Clustering Accuracy (CA): 0.45
#   Partition Coefficient (PC): 0.72
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.44
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: hausdorff_distance
#   Clustering Accuracy (CA): 0.02
#   Partition Coefficient (PC): 0.68
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 4.62
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: yang_chiclana_distance
#   Clustering Accuracy (CA): 0.56
#   Partition Coefficient (PC): 0.68
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 4.62
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: wang_xin_distance
#   Clustering Accuracy (CA): 0.02
#   Partition Coefficient (PC): 0.72
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.46
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: liu_jiang_distance
#   Clustering Accuracy (CA): 0.21
#   Partition Coefficient (PC): 0.72
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.44
#   Dunn Index (DI): 0.13
# ------------------------------------------------
# Measure: he_distance
#   Clustering Accuracy (CA): 0.11
#   Partition Coefficient (PC): 0.73
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.28
#   Dunn Index (DI): 0.02
# ------------------------------------------------
# Measure: thao_distance
#   Clustering Accuracy (CA): 0.21
#   Partition Coefficient (PC): 0.73
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.35
#   Dunn Index (DI): 0.12
# ------------------------------------------------
# Measure: mahanta_panda_distance
#   Clustering Accuracy (CA): 0.54
#   Partition Coefficient (PC): 0.73
#   Partition Index (SC): 0.02
#   Xie-Beni Index (XB): 3.31
#   Dunn Index (DI): 0.06
# ------------------------------------------------

# %%
M, N, H = al.method2_1(R_train, 0, 1, 0.45, 1)

M = np.around(M, 3)
N = np.around(N, 3)
H = np.around(H, 3)

# Chuẩn bị dữ liệu cho phân cụm
X = np.dstack((M, N, H))
P = X.shape[0]
true_labels = train[:, -1]

# Danh sách các hàm độ đo khoảng cách
distance_measures = {
    'distance_function': al.distance_function,
    'hamming_distance': al.hamming_distance,
    'euclidean_distance': al.euclidean_distance,
    'normalized_euclidean_distance': al.normalized_euclidean_distance,
    'hausdorff_distance': al.hausdorff_distance,
    'yang_chiclana_distance': al.yang_chiclana_distance,
    'wang_xin_distance': al.wang_xin_distance,
    'liu_jiang_distance': al.liu_jiang_distance,
    'he_distance': al.he_distance,
    'thao_distance': al.thao_distance,
    'mahanta_panda_distance': al.mahanta_panda_distance,
}

# Vòng lặp qua các độ đo
for measure_name, measure_func in distance_measures.items():
    # Phân cụm sử dụng độ đo hiện tại
    U, S = al.method3_1(R_train, len(np.unique(train[:, -1])), 1.7, 0.45,1, measure_name)

    # Gán nhãn dựa trên khoảng cách tới các tâm cụm
    y = np.array([np.argmin([measure_func(X[i], S[j]) for j in range(S.shape[0])]) for i in range(P)])

    # Tính toán các chỉ số đánh giá
    CA = round(al.calculate_CA(true_labels, y), 2)
    PC = round(al.calculate_PC(U), 2)
    SC = round(al.calculate_SC(X, U, S, 1.7), 2)
    XB = round(al.calculate_XB(X, U, S), 2)
    DI = round(al.calculate_DI(X, U), 2)

    # In ra các chỉ số đánh giá cho mỗi độ đo
    print(f'Measure: {measure_name}')
    print(f'  Clustering Accuracy (CA): {CA}')
    print(f'  Partition Coefficient (PC): {PC}')
    print(f'  Partition Index (SC): {SC}')
    print(f'  Xie-Beni Index (XB): {XB}')
    print(f'  Dunn Index (DI): {DI}')
    print('------------------------------------------------')
# Out:
# Measure: distance_function
#   Clustering Accuracy (CA): 0.65
#   Partition Coefficient (PC): 0.81
#   Partition Index (SC): 0.04
#   Xie-Beni Index (XB): 0.67
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: hamming_distance
#   Clustering Accuracy (CA): 0.63
#   Partition Coefficient (PC): 0.58
#   Partition Index (SC): 0.07
#   Xie-Beni Index (XB): 1.09
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: euclidean_distance
#   Clustering Accuracy (CA): 0.0
#   Partition Coefficient (PC): 0.56
#   Partition Index (SC): 0.08
#   Xie-Beni Index (XB): 1.26
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: normalized_euclidean_distance
#   Clustering Accuracy (CA): 0.0
#   Partition Coefficient (PC): 0.56
#   Partition Index (SC): 0.08
#   Xie-Beni Index (XB): 1.26
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: hausdorff_distance
#   Clustering Accuracy (CA): 0.0
#   Partition Coefficient (PC): 0.51
#   Partition Index (SC): 0.1
#   Xie-Beni Index (XB): 1.81
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: yang_chiclana_distance
#   Clustering Accuracy (CA): 0.0
#   Partition Coefficient (PC): 0.51
#   Partition Index (SC): 0.1
#   Xie-Beni Index (XB): 1.81
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: wang_xin_distance
#   Clustering Accuracy (CA): 0.06
#   Partition Coefficient (PC): 0.56
#   Partition Index (SC): 0.08
#   Xie-Beni Index (XB): 1.19
#   Dunn Index (DI): 0.37
# ------------------------------------------------
# Measure: liu_jiang_distance
#   Clustering Accuracy (CA): 0.38
#   Partition Coefficient (PC): 0.56
#   Partition Index (SC): 0.08
#   Xie-Beni Index (XB): 1.26
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: he_distance
#   Clustering Accuracy (CA): 0.37
#   Partition Coefficient (PC): 0.55
#   Partition Index (SC): 0.08
#   Xie-Beni Index (XB): 1.15
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: thao_distance
#   Clustering Accuracy (CA): 0.58
#   Partition Coefficient (PC): 0.65
#   Partition Index (SC): 0.06
#   Xie-Beni Index (XB): 1.02
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: mahanta_panda_distance
#   Clustering Accuracy (CA): 0.04
#   Partition Coefficient (PC): 0.58
#   Partition Index (SC): 0.07
#   Xie-Beni Index (XB): 1.09
#   Dunn Index (DI): 0.37
# ------------------------------------------------
