# %%
import algorithm as al
import numpy as np
import pandas as pd

# %%
# train = pd.read_excel('../archive/Raisin_Dataset.xlsx')
train = pd.read_csv('../data/haberman/haberman.data', header=None)
train
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
train = train.to_numpy()
R_train = train[:, 0:-1]
R_train
# R_train = np.random.rand(100, 10)
# Out:
# array([[30, 64,  1],
#        [30, 62,  3],
#        [30, 65,  0],
#        [31, 59,  2],
#        [31, 65,  4],
#        [33, 58, 10],
#        [33, 60,  0],
#        [34, 59,  0],
#        [34, 66,  9],
#        [34, 58, 30],
#        [34, 60,  1],
#        [34, 61, 10],
#        [34, 67,  7],
#        [34, 60,  0],
#        [35, 64, 13],
#        [35, 63,  0],
#        [36, 60,  1],
#        [36, 69,  0],
#        [37, 60,  0],
#        [37, 63,  0],
#        [37, 58,  0],
#        [37, 59,  6],
#        [37, 60, 15],
#        [37, 63,  0],
#        [38, 69, 21],
#        [38, 59,  2],
#        [38, 60,  0],
#        [38, 60,  0],
#        [38, 62,  3],
#        [38, 64,  1],
#        [38, 66,  0],
#        [38, 66, 11],
#        [38, 60,  1],
#        [38, 67,  5],
#        [39, 66,  0],
#        [39, 63,  0],
#        [39, 67,  0],
#        [39, 58,  0],
#        [39, 59,  2],
#        [39, 63,  4],
#        [40, 58,  2],
#        [40, 58,  0],
#        [40, 65,  0],
#        [41, 60, 23],
#        [41, 64,  0],
#        [41, 67,  0],
#        [41, 58,  0],
#        [41, 59,  8],
#        [41, 59,  0],
#        [41, 64,  0],
#        [41, 69,  8],
#        [41, 65,  0],
#        [41, 65,  0],
#        [42, 69,  1],
#        [42, 59,  0],
#        [42, 58,  0],
#        [42, 60,  1],
#        [42, 59,  2],
#        [42, 61,  4],
#        [42, 62, 20],
#        [42, 65,  0],
#        [42, 63,  1],
#        [43, 58, 52],
#        [43, 59,  2],
#        [43, 64,  0],
#        [43, 64,  0],
#        [43, 63, 14],
#        [43, 64,  2],
#        [43, 64,  3],
#        [43, 60,  0],
#        [43, 63,  2],
#        [43, 65,  0],
#        [43, 66,  4],
#        [44, 64,  6],
#        [44, 58,  9],
#        [44, 63, 19],
#        [44, 61,  0],
#        [44, 63,  1],
#        [44, 61,  0],
#        [44, 67, 16],
#        [45, 65,  6],
#        [45, 66,  0],
#        [45, 67,  1],
#        [45, 60,  0],
#        [45, 67,  0],
#        [45, 59, 14],
#        [45, 64,  0],
#        [45, 68,  0],
#        [45, 67,  1],
#        [46, 58,  2],
#        [46, 69,  3],
#        [46, 62,  5],
#        [46, 65, 20],
#        [46, 62,  0],
#        [46, 58,  3],
#        [46, 63,  0],
#        [47, 63, 23],
#        [47, 62,  0],
#        [47, 65,  0],
#        [47, 61,  0],
#        [47, 63,  6],
#        [47, 66,  0],
#        [47, 67,  0],
#        [47, 58,  3],
#        [47, 60,  4],
#        [47, 68,  4],
#        [47, 66, 12],
#        [48, 58, 11],
#        [48, 58, 11],
#        [48, 67,  7],
#        [48, 61,  8],
#        [48, 62,  2],
#        [48, 64,  0],
#        [48, 66,  0],
#        [49, 63,  0],
#        [49, 64, 10],
#        [49, 61,  1],
#        [49, 62,  0],
#        [49, 66,  0],
#        [49, 60,  1],
#        [49, 62,  1],
#        [49, 63,  3],
#        [49, 61,  0],
#        [49, 67,  1],
#        [50, 63, 13],
#        [50, 64,  0],
#        [50, 59,  0],
#        [50, 61,  6],
#        [50, 61,  0],
#        [50, 63,  1],
#        [50, 58,  1],
#        [50, 59,  2],
#        [50, 61,  0],
#        [50, 64,  0],
#        [50, 65,  4],
#        [50, 66,  1],
#        [51, 59, 13],
#        [51, 59,  3],
#        [51, 64,  7],
#        [51, 59,  1],
#        [51, 65,  0],
#        [51, 66,  1],
#        [52, 69,  3],
#        [52, 59,  2],
#        [52, 62,  3],
#        [52, 66,  4],
#        [52, 61,  0],
#        [52, 63,  4],
#        [52, 69,  0],
#        [52, 60,  4],
#        [52, 60,  5],
#        [52, 62,  0],
#        [52, 62,  1],
#        [52, 64,  0],
#        [52, 65,  0],
#        [52, 68,  0],
#        [53, 58,  4],
#        [53, 65,  1],
#        [53, 59,  3],
#        [53, 60,  9],
#        [53, 63, 24],
#        [53, 65, 12],
#        [53, 58,  1],
#        [53, 60,  1],
#        [53, 60,  2],
#        [53, 61,  1],
#        [53, 63,  0],
#        [54, 60, 11],
#        [54, 65, 23],
#        [54, 65,  5],
#        [54, 68,  7],
#        [54, 59,  7],
#        [54, 60,  3],
#        [54, 66,  0],
#        [54, 67, 46],
#        [54, 62,  0],
#        [54, 69,  7],
#        [54, 63, 19],
#        [54, 58,  1],
#        [54, 62,  0],
#        [55, 63,  6],
#        [55, 68, 15],
#        [55, 58,  1],
#        [55, 58,  0],
#        [55, 58,  1],
#        [55, 66, 18],
#        [55, 66,  0],
#        [55, 69,  3],
#        [55, 69, 22],
#        [55, 67,  1],
#        [56, 65,  9],
#        [56, 66,  3],
#        [56, 60,  0],
#        [56, 66,  2],
#        [56, 66,  1],
#        [56, 67,  0],
#        [56, 60,  0],
#        [57, 61,  5],
#        [57, 62, 14],
#        [57, 64,  1],
#        [57, 64,  9],
#        [57, 69,  0],
#        [57, 61,  0],
#        [57, 62,  0],
#        [57, 63,  0],
#        [57, 64,  0],
#        [57, 64,  0],
#        [57, 67,  0],
#        [58, 59,  0],
#        [58, 60,  3],
#        [58, 61,  1],
#        [58, 67,  0],
#        [58, 58,  0],
#        [58, 58,  3],
#        [58, 61,  2],
#        [59, 62, 35],
#        [59, 60,  0],
#        [59, 63,  0],
#        [59, 64,  1],
#        [59, 64,  4],
#        [59, 64,  0],
#        [59, 64,  7],
#        [59, 67,  3],
#        [60, 59, 17],
#        [60, 65,  0],
#        [60, 61,  1],
#        [60, 67,  2],
#        [60, 61, 25],
#        [60, 64,  0],
#        [61, 62,  5],
#        [61, 65,  0],
#        [61, 68,  1],
#        [61, 59,  0],
#        [61, 59,  0],
#        [61, 64,  0],
#        [61, 65,  8],
#        [61, 68,  0],
#        [61, 59,  0],
#        [62, 59, 13],
#        [62, 58,  0],
#        [62, 65, 19],
#        [62, 62,  6],
#        [62, 66,  0],
#        [62, 66,  0],
#        [62, 58,  0],
#        [63, 60,  1],
#        [63, 61,  0],
#        [63, 62,  0],
#        [63, 63,  0],
#        [63, 63,  0],
#        [63, 66,  0],
#        [63, 61,  9],
#        [63, 61, 28],
#        [64, 58,  0],
#        [64, 65, 22],
#        [64, 66,  0],
#        [64, 61,  0],
#        [64, 68,  0],
#        [65, 58,  0],
#        [65, 61,  2],
#        [65, 62, 22],
#        [65, 66, 15],
#        [65, 58,  0],
#        [65, 64,  0],
#        [65, 67,  0],
#        [65, 59,  2],
#        [65, 64,  0],
#        [65, 67,  1],
#        [66, 58,  0],
#        [66, 61, 13],
#        [66, 58,  0],
#        [66, 58,  1],
#        [66, 68,  0],
#        [67, 64,  8],
#        [67, 63,  1],
#        [67, 66,  0],
#        [67, 66,  0],
#        [67, 61,  0],
#        [67, 65,  0],
#        [68, 67,  0],
#        [68, 68,  0],
#        [69, 67,  8],
#        [69, 60,  0],
#        [69, 65,  0],
#        [69, 66,  0],
#        [70, 58,  0],
#        [70, 58,  4],
#        [70, 66, 14],
#        [70, 67,  0],
#        [70, 68,  0],
#        [70, 59,  8],
#        [70, 63,  0],
#        [71, 68,  2],
#        [72, 63,  0],
#        [72, 58,  0],
#        [72, 64,  0],
#        [72, 67,  3],
#        [73, 62,  0],
#        [73, 68,  0],
#        [74, 65,  3],
#        [74, 63,  0],
#        [75, 62,  1],
#        [76, 67,  0],
#        [77, 65,  3],
#        [78, 65,  1],
#        [83, 58,  2]], dtype=int64)

# %%
M, N, H = al.method1(R_train, 0.45)

M = np.around(M, 3)
N = np.around(N, 3)
H = np.around(H, 3)

print ("M = ",M)
print ("\nN = ",N)
print ("\nH = ",H)
# Out:
# M =  [[0.012 0.014 0.067]
#  [0.012 0.013 0.069]
#  [0.012 0.014 0.064]
#  [0.011 0.01  0.062]
#  [0.012 0.015 0.068]
#  [0.011 0.009 0.063]
#  [0.012 0.011 0.065]
#  [0.012 0.011 0.063]
#  [0.012 0.016 0.072]
#  [0.009 0.008 0.06 ]
#  [0.013 0.012 0.068]
#  [0.013 0.013 0.078]
#  [0.012 0.015 0.066]
#  [0.013 0.012 0.067]
#  [0.013 0.015 0.083]
#  [0.014 0.015 0.073]
#  [0.013 0.012 0.07 ]
#  [0.01  0.013 0.054]
#  [0.014 0.012 0.07 ]
#  [0.015 0.016 0.075]
#  [0.012 0.01  0.061]
#  [0.013 0.011 0.071]
#  [0.013 0.011 0.08 ]
#  [0.015 0.016 0.075]
#  [0.01  0.012 0.06 ]
#  [0.013 0.011 0.068]
#  [0.014 0.012 0.071]
#  [0.014 0.012 0.071]
#  [0.015 0.015 0.08 ]
#  [0.015 0.018 0.077]
#  [0.014 0.018 0.069]
#  [0.013 0.017 0.078]
#  [0.014 0.012 0.072]
#  [0.013 0.017 0.069]
#  [0.014 0.018 0.07 ]
#  [0.016 0.017 0.078]
#  [0.013 0.017 0.065]
#  [0.012 0.01  0.062]
#  [0.013 0.011 0.069]
#  [0.016 0.017 0.084]
#  [0.012 0.01  0.064]
#  [0.012 0.01  0.063]
#  [0.015 0.019 0.075]
#  [0.012 0.011 0.083]
#  [0.016 0.019 0.079]
#  [0.013 0.018 0.066]
#  [0.012 0.01  0.063]
#  [0.014 0.011 0.076]
#  [0.014 0.011 0.069]
#  [0.016 0.019 0.079]
#  [0.011 0.015 0.061]
#  [0.016 0.02  0.076]
#  [0.016 0.02  0.076]
#  [0.011 0.015 0.057]
#  [0.014 0.012 0.069]
#  [0.013 0.01  0.064]
#  [0.015 0.013 0.075]
#  [0.014 0.012 0.071]
#  [0.016 0.015 0.084]
#  [0.014 0.013 0.096]
#  [0.016 0.02  0.077]
#  [0.017 0.018 0.083]
#  [0.007 0.006 0.048]
#  [0.014 0.012 0.072]
#  [0.017 0.02  0.081]
#  [0.017 0.02  0.081]
#  [0.016 0.017 0.1  ]
#  [0.017 0.02  0.084]
#  [0.017 0.02  0.086]
#  [0.015 0.013 0.075]
#  [0.018 0.019 0.086]
#  [0.016 0.021 0.077]
#  [0.015 0.021 0.078]
#  [0.018 0.021 0.092]
#  [0.013 0.01  0.072]
#  [0.015 0.015 0.101]
#  [0.017 0.015 0.08 ]
#  [0.018 0.019 0.085]
#  [0.017 0.015 0.08 ]
#  [0.013 0.016 0.079]
#  [0.017 0.022 0.088]
#  [0.016 0.021 0.074]
#  [0.015 0.02  0.07 ]
#  [0.016 0.013 0.076]
#  [0.014 0.02  0.069]
#  [0.014 0.011 0.082]
#  [0.018 0.021 0.082]
#  [0.013 0.018 0.063]
#  [0.015 0.02  0.07 ]
#  [0.013 0.011 0.067]
#  [0.012 0.016 0.06 ]
#  [0.019 0.018 0.093]
#  [0.014 0.016 0.095]
#  [0.019 0.018 0.084]
#  [0.013 0.011 0.068]
#  [0.019 0.02  0.084]
#  [0.014 0.014 0.101]
#  [0.019 0.018 0.084]
#  [0.018 0.023 0.08 ]
#  [0.018 0.016 0.082]
#  [0.019 0.02  0.097]
#  [0.017 0.022 0.075]
#  [0.015 0.02  0.069]
#  [0.014 0.011 0.069]
#  [0.017 0.014 0.083]
#  [0.013 0.018 0.067]
#  [0.016 0.02  0.088]
#  [0.013 0.01  0.074]
#  [0.013 0.01  0.074]
#  [0.015 0.021 0.077]
#  [0.018 0.016 0.095]
#  [0.02  0.018 0.089]
#  [0.019 0.022 0.084]
#  [0.017 0.022 0.075]
#  [0.02  0.02  0.086]
#  [0.019 0.021 0.102]
#  [0.019 0.016 0.084]
#  [0.02  0.018 0.085]
#  [0.017 0.023 0.076]
#  [0.017 0.014 0.079]
#  [0.02  0.018 0.087]
#  [0.02  0.021 0.092]
#  [0.019 0.016 0.082]
#  [0.015 0.021 0.071]
#  [0.018 0.018 0.107]
#  [0.02  0.022 0.085]
#  [0.016 0.012 0.072]
#  [0.019 0.016 0.093]
#  [0.019 0.016 0.083]
#  [0.021 0.021 0.088]
#  [0.014 0.011 0.067]
#  [0.016 0.012 0.075]
#  [0.019 0.016 0.083]
#  [0.02  0.022 0.085]
#  [0.019 0.024 0.088]
#  [0.017 0.023 0.077]
#  [0.015 0.012 0.084]
#  [0.016 0.012 0.076]
#  [0.02  0.022 0.098]
#  [0.016 0.012 0.074]
#  [0.019 0.024 0.081]
#  [0.018 0.023 0.077]
#  [0.013 0.017 0.061]
#  [0.016 0.012 0.075]
#  [0.021 0.019 0.092]
#  [0.018 0.024 0.082]
#  [0.02  0.016 0.083]
#  [0.021 0.021 0.095]
#  [0.012 0.016 0.058]
#  [0.018 0.014 0.084]
#  [0.018 0.014 0.086]
#  [0.021 0.018 0.085]
#  [0.021 0.018 0.088]
#  [0.021 0.023 0.085]
#  [0.019 0.024 0.081]
#  [0.014 0.019 0.064]
#  [0.014 0.011 0.07 ]
#  [0.02  0.024 0.083]
#  [0.016 0.012 0.076]
#  [0.018 0.014 0.09 ]
#  [0.014 0.014 0.101]
#  [0.018 0.021 0.098]
#  [0.014 0.011 0.067]
#  [0.018 0.014 0.079]
#  [0.018 0.014 0.081]
#  [0.02  0.016 0.084]
#  [0.021 0.021 0.086]
#  [0.017 0.013 0.091]
#  [0.014 0.015 0.094]
#  [0.02  0.024 0.089]
#  [0.014 0.019 0.07 ]
#  [0.016 0.012 0.08 ]
#  [0.019 0.014 0.082]
#  [0.018 0.023 0.076]
#  [0.008 0.008 0.055]
#  [0.021 0.018 0.085]
#  [0.013 0.016 0.063]
#  [0.017 0.016 0.107]
#  [0.014 0.011 0.067]
#  [0.021 0.018 0.085]
#  [0.022 0.021 0.097]
#  [0.013 0.016 0.073]
#  [0.015 0.011 0.067]
#  [0.014 0.011 0.066]
#  [0.015 0.011 0.067]
#  [0.015 0.017 0.09 ]
#  [0.018 0.023 0.075]
#  [0.013 0.017 0.06 ]
#  [0.011 0.013 0.064]
#  [0.016 0.022 0.071]
#  [0.019 0.022 0.094]
#  [0.019 0.023 0.079]
#  [0.018 0.014 0.077]
#  [0.019 0.023 0.078]
#  [0.018 0.023 0.077]
#  [0.016 0.021 0.069]
#  [0.018 0.014 0.077]
#  [0.02  0.016 0.089]
#  [0.019 0.016 0.103]
#  [0.022 0.022 0.085]
#  [0.021 0.021 0.098]
#  [0.013 0.016 0.058]
#  [0.02  0.016 0.081]
#  [0.021 0.018 0.084]
#  [0.022 0.02  0.084]
#  [0.021 0.022 0.083]
#  [0.021 0.022 0.083]
#  [0.016 0.021 0.069]
#  [0.016 0.012 0.07 ]
#  [0.019 0.014 0.08 ]
#  [0.02  0.016 0.082]
#  [0.016 0.021 0.069]
#  [0.015 0.011 0.065]
#  [0.015 0.011 0.067]
#  [0.02  0.016 0.084]
#  [0.011 0.01  0.078]
#  [0.018 0.014 0.075]
#  [0.022 0.02  0.083]
#  [0.022 0.022 0.083]
#  [0.022 0.022 0.089]
#  [0.021 0.022 0.081]
#  [0.021 0.021 0.093]
#  [0.017 0.021 0.071]
#  [0.014 0.011 0.08 ]
#  [0.02  0.022 0.077]
#  [0.02  0.015 0.08 ]
#  [0.017 0.021 0.07 ]
#  [0.014 0.012 0.089]
#  [0.021 0.021 0.081]
#  [0.021 0.017 0.088]
#  [0.02  0.022 0.077]
#  [0.014 0.018 0.063]
#  [0.016 0.012 0.069]
#  [0.016 0.012 0.069]
#  [0.021 0.021 0.08 ]
#  [0.02  0.021 0.088]
#  [0.014 0.018 0.062]
#  [0.016 0.012 0.069]
#  [0.015 0.011 0.078]
#  [0.014 0.01  0.063]
#  [0.016 0.016 0.09 ]
#  [0.021 0.017 0.089]
#  [0.018 0.021 0.071]
#  [0.018 0.021 0.071]
#  [0.014 0.01  0.063]
#  [0.018 0.013 0.073]
#  [0.02  0.015 0.076]
#  [0.021 0.017 0.078]
#  [0.021 0.019 0.079]
#  [0.021 0.019 0.079]
#  [0.018 0.021 0.071]
#  [0.019 0.015 0.087]
#  [0.013 0.011 0.082]
#  [0.014 0.01  0.061]
#  [0.014 0.015 0.085]
#  [0.018 0.02  0.07 ]
#  [0.019 0.015 0.075]
#  [0.014 0.017 0.06 ]
#  [0.014 0.01  0.061]
#  [0.019 0.014 0.076]
#  [0.015 0.013 0.088]
#  [0.016 0.017 0.08 ]
#  [0.014 0.01  0.061]
#  [0.02  0.019 0.075]
#  [0.016 0.018 0.064]
#  [0.016 0.011 0.067]
#  [0.02  0.019 0.075]
#  [0.016 0.019 0.065]
#  [0.014 0.01  0.06 ]
#  [0.017 0.013 0.085]
#  [0.014 0.01  0.06 ]
#  [0.014 0.01  0.061]
#  [0.014 0.016 0.059]
#  [0.019 0.018 0.082]
#  [0.02  0.017 0.075]
#  [0.017 0.019 0.067]
#  [0.017 0.019 0.067]
#  [0.018 0.014 0.071]
#  [0.019 0.019 0.071]
#  [0.015 0.017 0.062]
#  [0.014 0.016 0.058]
#  [0.015 0.016 0.067]
#  [0.016 0.012 0.066]
#  [0.018 0.018 0.068]
#  [0.017 0.018 0.065]
#  [0.013 0.01  0.057]
#  [0.013 0.01  0.06 ]
#  [0.015 0.015 0.073]
#  [0.015 0.016 0.06 ]
#  [0.013 0.015 0.056]
#  [0.014 0.011 0.067]
#  [0.019 0.016 0.07 ]
#  [0.013 0.015 0.057]
#  [0.018 0.015 0.068]
#  [0.013 0.009 0.056]
#  [0.017 0.016 0.067]
#  [0.014 0.016 0.061]
#  [0.017 0.014 0.066]
#  [0.013 0.014 0.054]
#  [0.016 0.015 0.065]
#  [0.017 0.014 0.065]
#  [0.016 0.013 0.064]
#  [0.013 0.014 0.055]
#  [0.015 0.014 0.061]
#  [0.015 0.014 0.059]
#  [0.011 0.008 0.048]]
#
# N =  [[0.718 0.703 0.459]
#  [0.718 0.714 0.453]
#  [0.722 0.701 0.467]
#  [0.729 0.74  0.474]
#  [0.718 0.697 0.454]
#  [0.734 0.749 0.469]
#  [0.718 0.727 0.462]
#  [0.723 0.736 0.47 ]
#  [0.718 0.69  0.444]
#  [0.282 0.3   0.459]
#  [0.317 0.309 0.5  ]
#  [0.322 0.304 0.489]
#  [0.305 0.314 0.475]
#  [0.305 0.314 0.475]
#  [0.312 0.282 0.483]
#  [0.314 0.315 0.481]
#  [0.292 0.305 0.465]
#  [0.28  0.295 0.456]
#  [0.289 0.3   0.474]
#  [0.299 0.267 0.473]
#  [0.31  0.308 0.477]
#  [0.301 0.308 0.471]
#  [0.277 0.245 0.455]
#  [0.277 0.246 0.46 ]
#  [0.289 0.293 0.485]
#  [0.289 0.299 0.462]
#  [0.277 0.29  0.453]
#  [0.286 0.255 0.474]
#  [0.314 0.295 0.481]
#  [0.276 0.288 0.454]
#  [0.308 0.29  0.476]
#  [0.273 0.243 0.452]
#  [0.307 0.296 0.475]
#  [0.286 0.294 0.463]
#  [0.303 0.279 0.473]
#  [0.273 0.282 0.448]
#  [0.298 0.293 0.471]
#  [0.302 0.284 0.471]
#  [0.298 0.275 0.47 ]
#  [0.277 0.281 0.45 ]
#  [0.29  0.283 0.464]
#  [0.286 0.28  0.459]
#  [0.255 0.231 0.433]]

# %%
# Chuẩn bị dữ liệu cho phân cụm
X = np.dstack((M, N, H))
P = X.shape[0]
true_labels = train[:, -1]

# Danh sách các hàm độ đo khoảng cách
distance_measures = {
    'distance_function': al.distance_function,
    'hamming_distance': al.hamming_distance,
    'euclidean_distance': al.euclidean_distance,
    'normalized_euclidean_distance': al.normalized_euclidean_distance,
    'hausdorff_distance': al.hausdorff_distance,
    'yang_chiclana_distance': al.yang_chiclana_distance,
    'wang_xin_distance': al.wang_xin_distance,
    'liu_jiang_distance': al.liu_jiang_distance,
    'he_distance': al.he_distance,
    'thao_distance': al.thao_distance,
    'mahanta_panda_distance': al.mahanta_panda_distance,
}

# Vòng lặp qua các độ đo
for measure_name, measure_func in distance_measures.items():
    # Phân cụm sử dụng độ đo hiện tại
    U, S = al.method3(R_train, len(np.unique(train[:, -1])), 1.7, 0.45, measure_name)

    # Gán nhãn dựa trên khoảng cách tới các tâm cụm
    y = np.array([np.argmin([measure_func(X[i], S[j]) for j in range(S.shape[0])]) for i in range(P)])

    # Tính toán các chỉ số đánh giá
    CA = round(al.calculate_CA(true_labels, y), 2)
    PC = round(al.calculate_PC(U), 2)
    SC = round(al.calculate_SC(X, U, S, 1.7), 2)
    XB = round(al.calculate_XB(X, U, S), 2)
    DI = round(al.calculate_DI(X, U), 2)

    # In ra các chỉ số đánh giá cho mỗi độ đo
    print(f'Measure: {measure_name}')
    print(f'  Clustering Accuracy (CA): {CA}')
    print(f'  Partition Coefficient (PC): {PC}')
    print(f'  Partition Index (SC): {SC}')
    print(f'  Xie-Beni Index (XB): {XB}')
    print(f'  Dunn Index (DI): {DI}')
    print('------------------------------------------------')
# Out:
# Measure: distance_function
#   Clustering Accuracy (CA): 0.32
#   Partition Coefficient (PC): 0.82
#   Partition Index (SC): 0.19
#   Xie-Beni Index (XB): 3.56
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: hamming_distance
#   Clustering Accuracy (CA): 0.34
#   Partition Coefficient (PC): 0.65
#   Partition Index (SC): 0.35
#   Xie-Beni Index (XB): 5.0
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: euclidean_distance
#   Clustering Accuracy (CA): 0.33
#   Partition Coefficient (PC): 0.63
#   Partition Index (SC): 0.38
#   Xie-Beni Index (XB): 5.37
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: normalized_euclidean_distance
#   Clustering Accuracy (CA): 0.41
#   Partition Coefficient (PC): 0.63
#   Partition Index (SC): 0.38
#   Xie-Beni Index (XB): 5.37
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: hausdorff_distance
#   Clustering Accuracy (CA): 0.34
#   Partition Coefficient (PC): 0.62
#   Partition Index (SC): 0.46
#   Xie-Beni Index (XB): 6.29
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: yang_chiclana_distance
#   Clustering Accuracy (CA): 0.34
#   Partition Coefficient (PC): 0.62
#   Partition Index (SC): 0.46
#   Xie-Beni Index (XB): 6.29
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: wang_xin_distance
#   Clustering Accuracy (CA): 0.33
#   Partition Coefficient (PC): 0.64
#   Partition Index (SC): 0.37
#   Xie-Beni Index (XB): 5.22
#   Dunn Index (DI): 0.02
# ------------------------------------------------
# Measure: liu_jiang_distance
#   Clustering Accuracy (CA): 0.33
#   Partition Coefficient (PC): 0.63
#   Partition Index (SC): 0.38
#   Xie-Beni Index (XB): 5.37
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: he_distance
#   Clustering Accuracy (CA): 0.4
#   Partition Coefficient (PC): 0.66
#   Partition Index (SC): 0.34
#   Xie-Beni Index (XB): 4.95
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: thao_distance
#   Clustering Accuracy (CA): 0.38
#   Partition Coefficient (PC): 0.65
#   Partition Index (SC): 0.35
#   Xie-Beni Index (XB): 5.07
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: mahanta_panda_distance
#   Clustering Accuracy (CA): 0.34
#   Partition Coefficient (PC): 0.65
#   Partition Index (SC): 0.35
#   Xie-Beni Index (XB): 5.0
#   Dunn Index (DI): 0.03
# ------------------------------------------------

# %%
M, N, H = al.method2_1(R_train, 0, 1, 0.45, 1)

M = np.around(M, 3)
N = np.around(N, 3)
H = np.around(H, 3)

# Chuẩn bị dữ liệu cho phân cụm
X = np.dstack((M, N, H))
P = X.shape[0]
true_labels = train[:, -1]

# Danh sách các hàm độ đo khoảng cách
distance_measures = {
    'distance_function': al.distance_function,
    'hamming_distance': al.hamming_distance,
    'euclidean_distance': al.euclidean_distance,
    'normalized_euclidean_distance': al.normalized_euclidean_distance,
    'hausdorff_distance': al.hausdorff_distance,
    'yang_chiclana_distance': al.yang_chiclana_distance,
    'wang_xin_distance': al.wang_xin_distance,
    'liu_jiang_distance': al.liu_jiang_distance,
    'he_distance': al.he_distance,
    'thao_distance': al.thao_distance,
    'mahanta_panda_distance': al.mahanta_panda_distance,
}

# Vòng lặp qua các độ đo
for measure_name, measure_func in distance_measures.items():
    # Phân cụm sử dụng độ đo hiện tại
    U, S = al.method3_1(R_train, len(np.unique(train[:, -1])), 1.7, 0.45, measure_name)

    # Gán nhãn dựa trên khoảng cách tới các tâm cụm
    y = np.array([np.argmin([measure_func(X[i], S[j]) for j in range(S.shape[0])]) for i in range(P)])

    # Tính toán các chỉ số đánh giá
    CA = round(al.calculate_CA(true_labels, y), 2)
    PC = round(al.calculate_PC(U), 2)
    SC = round(al.calculate_SC(X, U, S, 1.7), 2)
    XB = round(al.calculate_XB(X, U, S), 2)
    DI = round(al.calculate_DI(X, U), 2)

    # In ra các chỉ số đánh giá cho mỗi độ đo
    print(f'Measure: {measure_name}')
    print(f'  Clustering Accuracy (CA): {CA}')
    print(f'  Partition Coefficient (PC): {PC}')
    print(f'  Partition Index (SC): {SC}')
    print(f'  Xie-Beni Index (XB): {XB}')
    print(f'  Dunn Index (DI): {DI}')
    print('------------------------------------------------')
# Out:
# Measure: distance_function
#   Clustering Accuracy (CA): 0.43
#   Partition Coefficient (PC): 0.7
#   Partition Index (SC): 0.71
#   Xie-Beni Index (XB): 0.98
#   Dunn Index (DI): 0.05
# ------------------------------------------------
# Measure: hamming_distance
#   Clustering Accuracy (CA): 0.27
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 1.5197030384006312e+16
#   Xie-Beni Index (XB): 1.7567870728470006e+16
#   Dunn Index (DI): 0.04
# ------------------------------------------------
# Measure: euclidean_distance
#   Clustering Accuracy (CA): 0.3
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 1483894960490127.8
#   Xie-Beni Index (XB): 1715392690663707.5
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: normalized_euclidean_distance
#   Clustering Accuracy (CA): 0.43
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 449329011202190.75
#   Xie-Beni Index (XB): 519427400214906.6
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: hausdorff_distance
#   Clustering Accuracy (CA): 0.3
#   Partition Coefficient (PC): 0.52
#   Partition Index (SC): 6.53
#   Xie-Beni Index (XB): 7.67
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: yang_chiclana_distance
#   Clustering Accuracy (CA): 0.3
#   Partition Coefficient (PC): 0.52
#   Partition Index (SC): 6.53
#   Xie-Beni Index (XB): 7.67
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: wang_xin_distance
#   Clustering Accuracy (CA): 0.47
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 1356821321641308.8
#   Xie-Beni Index (XB): 1568494697839939.0
#   Dunn Index (DI): 0.04
# ------------------------------------------------
# Measure: liu_jiang_distance
#   Clustering Accuracy (CA): 0.3
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 1487012414078970.0
#   Xie-Beni Index (XB): 1718996488265402.2
#   Dunn Index (DI): 0.03
# ------------------------------------------------
# Measure: he_distance
#   Clustering Accuracy (CA): 0.3
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 2.903163846576556e+16
#   Xie-Beni Index (XB): 3.3560771987335572e+16
#   Dunn Index (DI): 0.06
# ------------------------------------------------
# Measure: thao_distance
#   Clustering Accuracy (CA): 0.45
#   Partition Coefficient (PC): 0.53
#   Partition Index (SC): 4.57
#   Xie-Beni Index (XB): 5.42
#   Dunn Index (DI): 0.02
# ------------------------------------------------
# Measure: mahanta_panda_distance
#   Clustering Accuracy (CA): 0.47
#   Partition Coefficient (PC): 0.5
#   Partition Index (SC): 1675848036694230.0
#   Xie-Beni Index (XB): 1937291755380636.5
#   Dunn Index (DI): 0.04
# ------------------------------------------------
